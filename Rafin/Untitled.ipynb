# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Training Dataset

# %%
data = pd.read_csv("C:/Users/broth/Datathon/Robi_DataThon/Rafin/train.csv", encoding='latin-1')

# %%
data.head()
# Out:
#                                                   id gender s11 s12  s13 s16  \
# 0  b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1   D
# 1  b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1   D
# 2  b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1   D
# 3  b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1   D
# 4  b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1   B
#
#   s17 s18  s48 s52  ...        n7        n8        n9       n10       n11 n12  \
# 0   D   B    0   1  ... -9.126056  1.732291  3.698504  4.804517  1.544484   0
# 1   D   B    1   1  ... -9.098287  1.505885  6.791357  6.110416  1.712354   0
# 2   D   B    0   1  ... -9.234894  1.503828  4.109685  3.953226  1.804260   0
# 3   D   B    0   1  ... -9.378025  1.485863  7.265876  4.559419  1.537645   0
# 4   D   D    1   l  ... -9.261962  1.619210  3.737647  4.052003  1.637831   0
#
#    n13       n14 n15 label
# ...

# %% [markdown]
# #### Checking shape of the dataset

# %%
data.shape
# Out:
# (28322, 36)

# %% [markdown]
# #### Checking if there are any duplicate data

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Checking null Data

# %%
data.isnull().sum()
# Out:
# id            0
# gender        0
# s11           0
# s12           0
# s13           0
# s16           0
# s17           0
# s18           0
# s48           0
# s52           0
# s53           0
# s54       25694
# s55       25116
# s56       28322
# s57       28322
# s58           0
# s59       28322
# s69           0
# s70           0
# s71           0
# n1            0
# n2            0
# n3            0
# n4            0
# n5            0
# n6            0
# n7            0
# n8            0
# n9            0
# n10           0
# n11           0
# n12           0
# n13           0
# n14           0
# n15           0
# label         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28322 entries, 0 to 28321
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      28322 non-null  object
#  1   gender  28322 non-null  object
#  2   s11     28322 non-null  object
#  3   s12     28322 non-null  object
#  4   s13     28322 non-null  int64
#  5   s16     28322 non-null  object
#  6   s17     28322 non-null  object
#  7   s18     28322 non-null  object
#  8   s48     28322 non-null  int64
#  9   s52     28322 non-null  object
#  10  s53     28322 non-null  object
#  11  s54     2628 non-null   object
#  12  s55     3206 non-null   object
#  13  s56     0 non-null      float64
#  14  s57     0 non-null      float64
#  15  s58     28322 non-null  object
#  16  s59     0 non-null      float64
#  17  s69     28322 non-null  object
#  18  s70     28322 non-null  object
#  19  s71     28322 non-null  object
#  20  n1      28322 non-null  float64
# ...

# %%
data.corr()
# Out:
#             s13       s48  s56  s57  s59        n1        n2        n3  \
# s13    1.000000 -0.107237  NaN  NaN  NaN -0.059313 -0.059919  0.055319
# s48   -0.107237  1.000000  NaN  NaN  NaN -0.031168 -0.033586  0.051126
# s56         NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN
# s57         NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN
# s59         NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN
# n1    -0.059313 -0.031168  NaN  NaN  NaN  1.000000  0.855794  0.289057
# n2    -0.059919 -0.033586  NaN  NaN  NaN  0.855794  1.000000  0.321529
# n3     0.055319  0.051126  NaN  NaN  NaN  0.289057  0.321529  1.000000
# n4     0.012209 -0.088057  NaN  NaN  NaN  0.131877  0.154993  0.222131
# n5    -0.090193  0.007119  NaN  NaN  NaN  0.166290  0.135346 -0.056097
# n6    -0.094815 -0.116692  NaN  NaN  NaN  0.081274  0.026397 -0.425036
# n7     0.044618  0.026812  NaN  NaN  NaN  0.602224  0.624320  0.640050
# ...

# %% [markdown]
# #### Data Correlation with 'label'

# %%
data.corr()['label']
# Out:
# s13     -0.209406
# s48      0.248349
# s56           NaN
# s57           NaN
# s59           NaN
# n1       0.142913
# n2       0.120631
# n3      -0.123280
# n4      -0.069697
# n5       0.183936
# n6       0.168914
# n7      -0.033714
# n8       0.168010
# n9       0.042518
# n10     -0.047156
# n11     -0.002960
# n12     -0.001484
# n13      0.008253
# n14      0.005095
# n15     -0.002457
# label    1.000000
# Name: label, dtype: float64

# %% [markdown]
# #### Dropping s56, s57, s59 Null columns

# %%
data.drop(columns=['s56','s57','s59'], inplace=True)

# %%
data.head()
# Out:
#                                                   id gender s11 s12  s13 s16  \
# 0  b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1   D
# 1  b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1   D
# 2  b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1   D
# 3  b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1   D
# 4  b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1   B
#
#   s17 s18  s48 s52  ...        n7        n8        n9       n10       n11 n12  \
# 0   D   B    0   1  ... -9.126056  1.732291  3.698504  4.804517  1.544484   0
# 1   D   B    1   1  ... -9.098287  1.505885  6.791357  6.110416  1.712354   0
# 2   D   B    0   1  ... -9.234894  1.503828  4.109685  3.953226  1.804260   0
# 3   D   B    0   1  ... -9.378025  1.485863  7.265876  4.559419  1.537645   0
# 4   D   D    1   l  ... -9.261962  1.619210  3.737647  4.052003  1.637831   0
#
#   n13       n14  n15  label
# ...

# %%
data.corr()['label']
# Out:
# s13     -0.209406
# s48      0.248349
# n1       0.142913
# n2       0.120631
# n3      -0.123280
# n4      -0.069697
# n5       0.183936
# n6       0.168914
# n7      -0.033714
# n8       0.168010
# n9       0.042518
# n10     -0.047156
# n11     -0.002960
# n12     -0.001484
# n13      0.008253
# n14      0.005095
# n15     -0.002457
# label    1.000000
# Name: label, dtype: float64

# %% [markdown]
# #### Dropping id column

# %%
data.drop(columns=['id'], inplace=True)

# %%
data.head()
# Out:
#   gender s11 s12  s13 s16 s17 s18  s48 s52 s53  ...        n7        n8  \
# 0      M   Y   N    1   D   D   B    0   1      ... -9.126056  1.732291
# 1      M   Y   Y    1   D   D   B    1   1      ... -9.098287  1.505885
# 2      M   Y   Y    1   D   D   B    0   1      ... -9.234894  1.503828
# 3      F   Y   Y    1   D   D   B    0   1      ... -9.378025  1.485863
# 4      M   N   Y    1   B   D   D    1   l      ... -9.261962  1.619210
#
#          n9       n10       n11 n12  n13       n14  n15  label
# 0  3.698504  4.804517  1.544484   0    0  0.631220    5      0
# 1  6.791357  6.110416  1.712354   0    0  0.392746    3      1
# 2  4.109685  3.953226  1.804260   0    0  0.222537    2      0
# 3  7.265876  4.559419  1.537645   0    0  0.154409    4      0
# 4  3.737647  4.052003  1.637831   0    1  0.737560    1      0
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28322 entries, 0 to 28321
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  28322 non-null  object
#  1   s11     28322 non-null  object
#  2   s12     28322 non-null  object
#  3   s13     28322 non-null  int64
#  4   s16     28322 non-null  object
#  5   s17     28322 non-null  object
#  6   s18     28322 non-null  object
#  7   s48     28322 non-null  int64
#  8   s52     28322 non-null  object
#  9   s53     28322 non-null  object
#  10  s54     2628 non-null   object
#  11  s55     3206 non-null   object
#  12  s58     28322 non-null  object
#  13  s69     28322 non-null  object
#  14  s70     28322 non-null  object
#  15  s71     28322 non-null  object
#  16  n1      28322 non-null  float64
#  17  n2      28322 non-null  float64
#  18  n3      28322 non-null  int64
#  19  n4      28322 non-null  float64
#  20  n5      28322 non-null  float64
# ...

# %%
data['s55'].value_counts()
# Out:
# 2k    405
# 2K    400
# k2    364
# K2    359
# 22    345
# Kk    345
# KK    343
# kk    330
# kK    315
# Name: s55, dtype: int64

# %% [markdown]
# #### One Hot Encoding In column s54, s55, s58

# %%
one_hot_encoded_data = pd.get_dummies(data, columns = ['s55', 's58', 's54'])
one_hot_encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28322 entries, 0 to 28321
# Data columns (total 49 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  28322 non-null  object
#  1   s11     28322 non-null  object
#  2   s12     28322 non-null  object
#  3   s13     28322 non-null  int64
#  4   s16     28322 non-null  object
#  5   s17     28322 non-null  object
#  6   s18     28322 non-null  object
#  7   s48     28322 non-null  int64
#  8   s52     28322 non-null  object
#  9   s53     28322 non-null  object
#  10  s69     28322 non-null  object
#  11  s70     28322 non-null  object
#  12  s71     28322 non-null  object
#  13  n1      28322 non-null  float64
#  14  n2      28322 non-null  float64
#  15  n3      28322 non-null  int64
#  16  n4      28322 non-null  float64
#  17  n5      28322 non-null  float64
#  18  n6      28322 non-null  float64
#  19  n7      28322 non-null  float64
#  20  n8      28322 non-null  float64
# ...

# %%
one_hot_encoded_data.corr()['label']
# Out:
# s13      -0.209406
# s48       0.248349
# n1        0.142913
# n2        0.120631
# n3       -0.123280
# n4       -0.069697
# n5        0.183936
# n6        0.168914
# n7       -0.033714
# n8        0.168010
# n9        0.042518
# n10      -0.047156
# n11      -0.002960
# n12      -0.001484
# n13       0.008253
# n14       0.005095
# n15      -0.002457
# label     1.000000
# s55_22   -0.002568
# s55_2K   -0.001782
# s55_2k   -0.003235
# s55_K2    0.003937
# s55_KK    0.004621
# s55_Kk   -0.009454
# s55_k2   -0.005178
# s55_kK    0.009957
# s55_kk   -0.003046
# s58_A     0.005403
# s58_B    -0.005403
# s54_22    0.004446
# s54_2a   -0.010214
# s54_2b   -0.000098
# s54_a2    0.011026
# s54_aa   -0.003270
# s54_ab   -0.001776
# s54_b2    0.001106
# s54_ba   -0.002107
# s54_bb    0.019111
# Name: label, dtype: float64

# %%
data['s58'].value_counts()
# Out:
# B    25760
# A     2562
# Name: s58, dtype: int64

# %%
data.drop(columns=['s54', 's55'], inplace=True)

# %%
data['s52'].value_counts()
# Out:
# 1    20524
# l     6508
# 0     1094
# o      196
# Name: s52, dtype: int64

# %%
data.corr()['label']
# Out:
# s13     -0.209406
# s48      0.248349
# n1       0.142913
# n2       0.120631
# n3      -0.123280
# n4      -0.069697
# n5       0.183936
# n6       0.168914
# n7      -0.033714
# n8       0.168010
# n9       0.042518
# n10     -0.047156
# n11     -0.002960
# n12     -0.001484
# n13      0.008253
# n14      0.005095
# n15     -0.002457
# label    1.000000
# Name: label, dtype: float64

# %% [markdown]
# # s53 Conversion Starts

# %%
data['s53'].value_counts()
# Out:
#       25752
#        2570
# Name: s53, dtype: int64

# %%
def s53_convert(text):
    if text == ' ':
        return '1'
    else:
        return '0'

# %%
data['s53'].value_counts()
# Out:
#       25752
#        2570
# Name: s53, dtype: int64

# %%
data['s53mod']= data['s53'].apply(s53_convert)

# %%
data['s53mod'].value_counts()
# Out:
# 0    25752
# 1     2570
# Name: s53mod, dtype: int64

# %%
data.corr()['label']
# Out:
# s13     -0.209406
# s48      0.248349
# n1       0.142913
# n2       0.120631
# n3      -0.123280
# n4      -0.069697
# n5       0.183936
# n6       0.168914
# n7      -0.033714
# n8       0.168010
# n9       0.042518
# n10     -0.047156
# n11     -0.002960
# n12     -0.001484
# n13      0.008253
# n14      0.005095
# n15     -0.002457
# label    1.000000
# Name: label, dtype: float64

# %%
data['s53']=data['s53mod'].astype(str).astype(int)

# %%
data.corr()['label']
# Out:
# s13     -0.209406
# s48      0.248349
# s53      0.001008
# n1       0.142913
# n2       0.120631
# n3      -0.123280
# n4      -0.069697
# n5       0.183936
# n6       0.168914
# n7      -0.033714
# n8       0.168010
# n9       0.042518
# n10     -0.047156
# n11     -0.002960
# n12     -0.001484
# n13      0.008253
# n14      0.005095
# n15     -0.002457
# label    1.000000
# Name: label, dtype: float64

# %%
data.drop(columns=['s53'], inplace=True)

# %% [markdown]
# # s53 Conversion and Dropping Ends

# %%
data.corr()['label']
# Out:
# s13     -0.209406
# s48      0.248349
# n1       0.142913
# n2       0.120631
# n3      -0.123280
# n4      -0.069697
# n5       0.183936
# n6       0.168914
# n7      -0.033714
# n8       0.168010
# n9       0.042518
# n10     -0.047156
# n11     -0.002960
# n12     -0.001484
# n13      0.008253
# n14      0.005095
# n15     -0.002457
# label    1.000000
# Name: label, dtype: float64
